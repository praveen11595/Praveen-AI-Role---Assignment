# %%
pip install opencv-python opencv-python-headless numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\yprav\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: opencv-python-headless in c:\users\yprav\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy in c:\users\yprav\anaconda3\lib\site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import time

# %%
cap = cv2.VideoCapture(r"C:\Users\yprav\Downloads\AI Assignment video.mp4")

# %%
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, fps, (width, height))
start_time = time.time()

# %%
def get_quadrant(x, y, width, height):
    if x < width // 2 and y < height // 2:
        return 1
    elif x >= width // 2 and y < height // 2:
        return 2
    elif x < width // 2 and y >= height // 2:
        return 3
    else:
        return 4

# %%
def detect_balls(frame):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    color_ranges = {
        'red': [(0, 70, 50), (10, 255, 255)],
        'blue': [(100, 150, 0), (140, 255, 255)],
        'green': [(40, 70, 70), (80, 255, 255)]
    }

    balls = []

    for color, (lower, upper) in color_ranges.items():
        mask = cv2.inRange(hsv, np.array(lower), np.array(upper))
        contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        
        for cnt in contours:
            approx = cv2.approxPolyDP(cnt, 0.02*cv2.arcLength(cnt, True), True)
            (x, y, w, h) = cv2.boundingRect(approx)
            if w > 20 and h > 20:  # Size filter
                balls.append((x + w // 2, y + h // 2, color))

    return balls

# %%
event_log = []

previous_positions = {}

def log_event(ball_id, color, quadrant, event_type, timestamp):
    event_log.append(f"{timestamp:.2f}, {quadrant}, {color}, {event_type}")
    print(f"{timestamp:.2f}, {quadrant}, {color}, {event_type}")

frame_id = 0

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    current_time = time.time() - start_time
    balls = detect_balls(frame)

    for ball in balls:
        x, y, color = ball
        quadrant = get_quadrant(x, y, width, height)
        ball_id = f"{color}_{x}_{y}"

        if ball_id not in previous_positions:
            log_event(ball_id, color, quadrant, "Entry", current_time)
        else:
            prev_x, prev_y = previous_positions[ball_id]
            prev_quadrant = get_quadrant(prev_x, prev_y, width, height)
            if prev_quadrant != quadrant:
                log_event(ball_id, color, prev_quadrant, "Exit", current_time)
                log_event(ball_id, color, quadrant, "Entry", current_time)

        previous_positions[ball_id] = (x, y)

    cv2.line(frame, (width // 2, 0), (width // 2, height), (255, 255, 255), 2)
    cv2.line(frame, (0, height // 2), (width, height // 2), (255, 255, 255), 2)

    for ball in balls:
        x, y, color = ball
        cv2.circle(frame, (x, y), 10, (0, 0, 255), -1)  # Example color

    out.write(frame)
    frame_id += 1

cap.release()
out.release()

with open('events.txt', 'w') as f:
    for event in event_log:
        f.write(event + '\n')
# Out:
# 0.08, 2, red, Entry
# 0.08, 2, red, Entry
# 0.08, 1, red, Entry
# 0.08, 4, blue, Entry
# 0.08, 2, blue, Entry
# 0.08, 2, blue, Entry
# 0.12, 3, red, Entry
# 0.12, 1, red, Entry
# 0.12, 1, red, Entry
# 0.12, 4, blue, Entry
# 0.12, 2, blue, Entry
# 0.15, 3, red, Entry
# 0.15, 4, red, Entry
# 0.15, 3, red, Entry
# 0.15, 2, red, Entry
# 0.19, 3, red, Entry
# 0.19, 4, red, Entry
# 0.19, 4, red, Entry
# 0.19, 3, red, Entry
# 0.19, 2, red, Entry
# 0.19, 1, red, Entry
# 0.23, 4, red, Entry
# 0.23, 2, red, Entry
# 0.23, 2, red, Entry
# 0.23, 2, blue, Entry
# 0.27, 4, red, Entry
# 0.27, 3, red, Entry
# 0.27, 2, red, Entry
# 0.27, 2, blue, Entry
# 0.31, 3, red, Entry
# 0.31, 4, red, Entry
# 0.31, 2, red, Entry
# 0.31, 1, red, Entry
# 0.35, 3, red, Entry
# 0.38, 3, red, Entry
# 0.38, 1, red, Entry
# 0.38, 2, blue, Entry
# 0.42, 3, red, Entry
# 0.42, 3, red, Entry
# 0.42, 2, red, Entry
# 0.42, 1, red, Entry
# 0.42, 2, blue, Entry
# 0.46, 3, red, Entry
# 0.46, 3, red, Entry
# 0.46, 4, red, Entry
# 0.46, 3, red, Entry
# 0.46, 2, red, Entry
# 0.46, 2, blue, Entry
# 0.50, 3, red, Entry
# 0.50, 3, red, Entry
# 0.50, 3, red, Entry
# 0.54, 4, red, Entry
# 0.54, 3, red, Entry
# 0.54, 1, red, Entry
# 0.58, 3, red, Entry
# 0.58, 1, red, Entry
# 0.62, 4, red, Entry
# 0.62, 3, red, Entry
# 0.62, 1, red, Entry
# 0.62, 2, red, Entry
# 0.66, 3, red, Entry
# 0.66, 3, red, Entry
# 0.66, 1, red, Entry
# 0.69, 3, red, Entry
# 0.69, 4, red, Entry
# 0.73, 3, red, Entry
# 0.73, 4, red, Entry
# 0.73, 3, red, Entry
# 0.73, 4, blue, Entry
# 0.73, 2, blue, Entry
# 0.77, 3, red, Entry
# 0.77, 4, red, Entry
# 0.77, 1, red, Entry
# 0.77, 1, red, Entry
# 0.77, 4, blue, Entry
# 0.81, 3, red, Entry
# 0.81, 2, red, Entry
# 0.85, 3, red, Entry
# 0.85, 3, red, Entry
# 0.85, 2, red, Entry
# 0.85, 1, red, Entry
# 0.90, 3, red, Entry
# 0.90, 4, red, Entry
# 0.90, 3, red, Entry
# 0.90, 2, red, Entry
# 0.90, 1, red, Entry
# 0.93, 3, red, Entry
# 0.93, 2, blue, Entry
# 0.97, 3, red, Entry
# 0.97, 2, red, Entry
# 1.01, 3, red, Entry
# 1.01, 2, red, Entry
# 1.01, 1, red, Entry
# 1.05, 3, red, Entry
# 1.05, 2, red, Entry
# 1.09, 3, red, Entry
# 1.09, 3, red, Entry
# 1.09, 2, red, Entry
# 1.09, 2, red, Entry
# 1.13, 3, red, Entry
# 1.13, 3, red, Entry
# 1.13, 1, red, Entry
# 1.17, 3, red, Entry
# 1.17, 1, red, Entry
# 1.20, 3, red, Entry
# 1.20, 4, red, Entry
# 1.20, 4, blue, Entry
# 1.25, 3, red, Entry
# 1.25, 4, red, Entry
# 1.25, 4, red, Entry
# 1.25, 3, red, Entry
# 1.25, 2, red, Entry
# 1.25, 2, red, Entry
# 1.25, 1, red, Entry
# 1.30, 3, red, Entry
# 1.30, 4, red, Entry
# 1.30, 3, red, Entry
# 1.30, 1, red, Entry
# 1.30, 2, red, Entry
# 1.33, 3, red, Entry
# 1.33, 3, red, Entry
# 1.33, 4, red, Entry
# 1.33, 1, red, Entry
# 1.38, 3, red, Entry
# 1.38, 3, red, Entry
# 1.38, 3, red, Entry
# 1.38, 2, red, Entry
# 1.38, 2, blue, Entry
# 1.42, 3, red, Entry
# 1.42, 3, red, Entry
# 1.46, 3, red, Entry
# 1.46, 3, red, Entry
# 1.46, 1, red, Entry
# 1.50, 3, red, Entry
# 1.50, 3, red, Entry
# 1.50, 3, red, Entry
# 1.50, 3, red, Entry
# 1.50, 2, blue, Entry
# 1.54, 3, red, Entry
# 1.54, 3, red, Entry
# 1.54, 1, red, Entry
# 1.58, 3, red, Entry
# 1.58, 1, red, Entry
# 1.58, 1, red, Entry
# 1.61, 3, red, Entry
# 1.61, 3, red, Entry
# 1.61, 1, red, Entry
# 1.65, 3, red, Entry
# 1.65, 1, red, Entry
# 1.65, 4, blue, Entry
# 1.69, 3, red, Entry
# 1.69, 4, red, Entry
# 1.69, 4, blue, Entry
# 1.73, 3, red, Entry
# 1.73, 3, red, Entry
# 1.73, 3, red, Entry
# 1.77, 3, red, Entry
# 1.77, 3, red, Entry
# 1.81, 3, red, Entry
# 1.81, 3, red, Entry
# 1.81, 2, red, Entry
# 1.85, 4, red, Entry
# 1.85, 3, red, Entry
# 1.89, 3, red, Entry
# 1.89, 3, red, Entry
# 1.92, 3, red, Entry
# 1.92, 3, red, Entry
# 1.92, 2, red, Entry
# 1.97, 3, red, Entry
# 1.97, 4, red, Entry
# 1.97, 3, red, Entry
# 2.00, 4, red, Entry
# 2.04, 3, red, Entry
# 2.04, 3, red, Entry
# 2.04, 4, red, Entry
# 2.04, 2, red, Entry
# 2.07, 3, red, Entry
# 2.07, 3, red, Entry
# 2.10, 3, red, Entry
# 2.10, 4, red, Entry
# 2.10, 3, red, Entry
# 2.10, 1, red, Entry
# 2.16, 3, red, Entry
# 2.16, 3, red, Entry
# 2.16, 2, red, Entry
# 2.19, 3, red, Entry
# 2.19, 3, red, Entry
# 2.19, 3, red, Entry
# 2.19, 2, red, Entry
# 2.19, 2, blue, Entry
# 2.23, 3, red, Entry
# 2.23, 3, red, Entry
# 2.23, 2, red, Entry
# 2.26, 3, red, Entry
# 2.26, 3, red, Entry
# 2.26, 1, red, Entry
# 2.31, 3, red, Entry
# 2.31, 3, red, Entry
# 2.31, 1, red, Entry
# 2.31, 2, blue, Entry
# 2.35, 3, red, Entry
# 2.35, 3, red, Entry
# 2.40, 4, red, Entry
# 2.40, 3, red, Entry
# 2.43, 3, red, Entry
# 2.43, 4, red, Entry
# 2.43, 4, red, Entry
# 2.43, 4, red, Entry
# 2.43, 4, red, Entry
# 2.43, 4, red, Entry
# 2.43, 3, red, Entry
# 2.43, 4, red, Entry
# 2.43, 4, red, Entry
# 2.43, 1, red, Entry
# 2.43, 2, blue, Entry
# 2.48, 3, red, Entry
# 2.48, 4, red, Entry
# 2.48, 3, red, Entry
# 2.48, 4, red, Entry
# 2.48, 3, red, Entry
# 2.48, 4, red, Entry
# 2.48, 4, red, Entry
# 2.48, 4, red, Entry
# 2.48, 4, red, Entry
# 2.48, 4, red, Entry
# 2.48, 4, red, Entry
# 2.48, 4, red, Entry
# 2.48, 1, red, Entry
# 2.48, 2, red, Entry
# 2.48, 4, blue, Entry
# 2.51, 3, red, Entry
# 2.51, 4, red, Entry
# 2.51, 4, red, Entry
# 2.51, 3, red, Entry
# 2.51, 4, red, Entry
# 2.51, 3, red, Entry
# 2.51, 3, red, Entry
# 2.51, 4, red, Entry
# 2.51, 4, red, Entry
# 2.51, 4, red, Entry
# 2.51, 4, red, Entry
# 2.51, 4, red, Entry
# 2.51, 4, red, Entry
# 2.51, 2, red, Entry
# 2.54, 4, red, Entry
# 2.54, 3, red, Entry
# 2.54, 4, red, Entry
# 2.54, 4, red, Entry
# 2.54, 4, red, Entry
# 2.54, 4, red, Entry
# 2.54, 4, red, Entry
# 2.54, 3, red, Entry
# 2.54, 2, red, Entry
# 2.54, 2, red, Entry
# 2.54, 4, red, Entry
# 2.54, 4, red, Entry
# 2.54, 4, red, Entry
# 2.54, 4, red, Entry
# 2.54, 2, red, Entry
# 2.60, 3, red, Entry
# 2.60, 4, red, Entry
# 2.60, 4, red, Entry
# 2.60, 4, red, Entry
# 2.60, 4, red, Entry
# 2.60, 2, red, Entry
# 2.60, 4, red, Entry
# 2.60, 4, red, Entry
# 2.60, 4, red, Entry
# 2.60, 2, red, Entry
# 2.60, 2, red, Entry
# 2.60, 2, red, Entry
# 2.60, 2, red, Entry
# 2.64, 3, red, Entry
# 2.64, 4, red, Entry
# 2.64, 4, red, Entry
# 2.64, 4, red, Entry
# 2.64, 4, red, Entry
# 2.64, 2, red, Entry
# 2.64, 2, red, Entry
# 2.64, 2, red, Entry
# 2.64, 1, red, Entry
# 2.64, 4, red, Entry
# 2.64, 2, red, Entry
# 2.64, 2, red, Entry
# 2.64, 2, red, Entry
# 2.64, 2, red, Entry
# 2.68, 4, red, Entry
# 2.68, 4, red, Entry
# 2.68, 4, red, Entry
# 2.68, 4, red, Entry
# 2.68, 2, red, Entry
# 2.68, 4, red, Entry
# 2.68, 4, red, Entry
# 2.68, 4, red, Entry
# 2.72, 4, red, Entry
# 2.72, 4, red, Entry
# 2.72, 2, red, Entry
# 2.72, 4, red, Entry
# 2.72, 2, red, Entry
# 2.72, 2, red, Entry
# 2.72, 2, red, Entry
# 2.72, 2, red, Entry
# 2.72, 4, red, Entry
# 2.72, 4, red, Entry
# 2.72, 4, red, Entry
# 2.72, 2, red, Entry
# 2.72, 2, red, Entry
# 2.72, 2, red, Entry
# 2.77, 4, red, Entry
# 2.77, 4, red, Entry
# 2.77, 3, red, Entry
# 2.77, 2, red, Entry
# 2.77, 2, red, Entry
# 2.77, 2, red, Entry
# 2.77, 4, red, Entry
# 2.77, 4, red, Entry
# 2.77, 4, red, Entry
# 2.77, 4, red, Entry
# 2.77, 2, red, Entry
# 2.77, 2, red, Entry
# 2.77, 2, red, Entry
# 2.81, 3, red, Entry
# 2.81, 4, red, Entry
# 2.81, 4, red, Entry
# 2.81, 4, red, Entry
# 2.81, 3, red, Entry
# 2.81, 2, red, Entry
# 2.81, 2, red, Entry
# 2.81, 2, red, Entry
# 2.81, 4, red, Entry
# 2.81, 4, red, Entry
# 2.81, 4, red, Entry
# 2.81, 4, red, Entry
# 2.81, 2, red, Entry
# 2.81, 2, red, Entry
# 2.81, 2, red, Entry
# 2.81, 2, red, Entry
# 2.81, 4, blue, Entry
# 2.86, 3, red, Entry
# 2.86, 2, red, Entry
# 2.86, 2, red, Entry
# 2.86, 4, red, Entry
# 2.86, 4, red, Entry
# 2.86, 4, red, Entry
# 2.86, 4, red, Entry
# 2.86, 4, red, Entry
# 2.86, 4, red, Entry
# 2.86, 2, red, Entry
# 2.86, 2, red, Entry
# 2.86, 2, red, Entry
# 2.86, 2, red, Entry
# 2.86, 2, red, Entry
# 2.91, 3, red, Entry
# 2.91, 4, red, Entry
# 2.91, 2, red, Entry
# 2.91, 2, red, Entry
# 2.91, 2, red, Entry
# 2.91, 2, red, Entry
# 2.91, 4, red, Entry
# 2.91, 4, red, Entry
# 2.91, 4, red, Entry
# 2.91, 4, red, Entry
# 2.91, 4, red, Entry
# 2.91, 4, red, Entry
# 2.91, 4, red, Entry
# 2.91, 2, red, Entry
# 2.91, 2, red, Entry
# 2.91, 2, red, Entry
# 2.91, 2, red, Entry
# 2.95, 3, red, Entry
# 2.95, 4, red, Entry
# 2.95, 3, red, Entry
# 2.95, 4, red, Entry
# 2.95, 3, red, Entry
# 2.95, 4, red, Entry
# 2.95, 2, red, Entry
# 2.95, 2, red, Entry
# 2.95, 1, red, Entry
# 2.95, 4, red, Entry
# 2.95, 4, red, Entry
# 2.95, 4, red, Entry
# 2.95, 4, red, Entry
# 2.95, 4, red, Entry
# 2.95, 4, red, Entry
# 2.95, 2, red, Entry
# 2.95, 2, red, Entry
# 2.95, 2, red, Entry
# 2.95, 2, red, Entry
# 2.95, 2, red, Entry
# 3.00, 3, red, Entry
# 3.00, 4, red, Entry
# 3.00, 3, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 1, red, Entry
# 3.00, 2, red, Entry
# 3.00, 2, red, Entry
# 3.00, 2, red, Entry
# 3.00, 2, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 4, red, Entry
# 3.00, 2, red, Entry
# 3.00, 2, red, Entry
# 3.00, 2, red, Entry
# 3.00, 2, red, Entry
# 3.00, 2, red, Entry
# 3.05, 4, red, Entry
# 3.05, 3, red, Entry
# 3.05, 4, red, Entry
# 3.05, 3, red, Entry
# 3.05, 4, red, Entry
# 3.05, 4, red, Entry
# 3.05, 2, red, Entry
# 3.05, 4, red, Entry
# 3.05, 4, red, Entry
# 3.05, 4, red, Entry
# 3.05, 4, red, Entry
# 3.05, 4, red, Entry
# 3.05, 2, red, Entry
# 3.05, 2, red, Entry
# 3.05, 2, red, Entry
# 3.05, 2, red, Entry
# 3.09, 4, red, Entry
# 3.09, 3, red, Entry
# 3.09, 3, red, Entry
# 3.09, 4, red, Entry
# 3.09, 4, red, Entry
# 3.09, 4, red, Entry
# 3.09, 4, red, Entry
# 3.09, 3, red, Entry
# 3.09, 2, red, Entry
# 3.09, 2, red, Entry
# 3.09, 2, red, Entry
# 3.09, 4, red, Entry
# 3.09, 4, red, Entry
# 3.09, 4, red, Entry
# 3.09, 4, red, Entry
# 3.09, 4, red, Entry
# 3.09, 2, red, Entry
# 3.09, 2, red, Entry
# 3.09, 2, red, Entry
# 3.09, 2, red, Entry
# 3.14, 3, red, Entry
# 3.14, 3, red, Entry
# 3.14, 4, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.14, 4, red, Entry
# 3.14, 4, red, Entry
# 3.14, 4, red, Entry
# 3.14, 4, red, Entry
# 3.14, 4, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.14, 2, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 3, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 2, red, Entry
# 3.19, 2, red, Entry
# 3.19, 2, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 4, red, Entry
# 3.19, 2, red, Entry
# 3.19, 2, red, Entry
# 3.19, 2, red, Entry
# 3.19, 2, red, Entry
# 3.19, 2, red, Entry
# 3.19, 2, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 3, red, Entry
# 3.24, 4, red, Entry
# 3.24, 2, red, Entry
# 3.24, 2, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 4, red, Entry
# 3.24, 2, red, Entry
# 3.24, 2, red, Entry
# 3.24, 2, red, Entry
# 3.24, 2, red, Entry
# 3.24, 2, red, Entry
# 3.24, 2, red, Entry
# 3.29, 3, red, Entry
# 3.29, 4, red, Entry
# 3.29, 3, red, Entry
# 3.29, 3, red, Entry
# 3.29, 4, red, Entry
# 3.29, 4, red, Entry
# 3.29, 3, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 4, red, Entry
# 3.29, 4, red, Entry
# 3.29, 4, red, Entry
# 3.29, 4, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 2, red, Entry
# 3.29, 4, blue, Entry
# 3.34, 3, red, Entry
# 3.34, 3, red, Entry
# 3.34, 4, red, Entry
# 3.34, 3, red, Entry
# 3.34, 2, red, Entry
# 3.34, 2, red, Entry
# 3.34, 4, red, Entry
# 3.34, 4, red, Entry
# 3.34, 4, red, Entry
# 3.34, 4, red, Entry
# 3.34, 4, red, Entry
# 3.34, 4, red, Entry
# 3.34, 4, red, Entry
# 3.34, 4, red, Entry
# 3.34, 2, red, Entry
# 3.34, 2, red, Entry
# 3.34, 2, red, Entry
# 3.34, 2, red, Entry
# 3.34, 2, red, Entry
# 3.34, 2, red, Entry
# 3.34, 2, red, Entry
# 3.39, 4, red, Entry
# 3.39, 3, red, Entry
# 3.39, 4, red, Entry
# 3.39, 4, red, Entry
# 3.39, 3, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 4, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 2, red, Entry
# 3.39, 1, red, Entry
# 3.43, 3, red, Entry
# 3.43, 4, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 4, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 4, red, Entry
# 3.43, 4, red, Entry
# 3.43, 4, red, Entry
# 3.43, 4, red, Entry
# 3.43, 4, red, Entry
# 3.43, 4, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.43, 2, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 2, red, Entry
# 3.48, 2, red, Entry
# 3.48, 4, red, Entry
# 3.48, 2, red, Entry
# 3.48, 2, red, Entry
# 3.48, 2, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 4, red, Entry
# 3.48, 2, red, Entry
# 3.48, 2, red, Entry
# 3.48, 2, red, Entry
# 3.48, 2, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 2, red, Entry
# 3.53, 2, red, Entry
# 3.53, 4, red, Entry
# 3.53, 2, red, Entry
# 3.53, 2, red, Entry
# 3.53, 2, red, Entry
# 3.53, 2, red, Entry
# 3.53, 2, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 4, red, Entry
# 3.53, 2, red, Entry
# 3.53, 2, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 2, red, Entry
# 3.57, 4, red, Entry
# 3.57, 2, red, Entry
# 3.57, 2, red, Entry
# 3.57, 2, red, Entry
# 3.57, 2, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 4, red, Entry
# 3.57, 2, red, Entry
# 3.57, 2, red, Entry
# 3.57, 2, red, Entry
# 3.57, 2, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 2, red, Entry
# 3.62, 2, red, Entry
# 3.62, 4, red, Entry
# 3.62, 2, red, Entry
# 3.62, 2, red, Entry
# 3.62, 2, red, Entry
# 3.62, 2, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 4, red, Entry
# 3.62, 2, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 4, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, red, Entry
# 3.67, 2, blue, Entry
# 3.72, 3, red, Entry
# 3.72, 3, red, Entry
# 3.72, 4, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.72, 4, red, Entry
# 3.72, 4, red, Entry
# 3.72, 4, red, Entry
# 3.72, 4, red, Entry
# 3.72, 4, red, Entry
# 3.72, 4, red, Entry
# 3.72, 4, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.72, 2, red, Entry
# 3.77, 4, red, Entry
# 3.77, 4, red, Entry
# 3.77, 4, red, Entry
# 3.77, 4, red, Entry
# 3.77, 2, red, Entry
# 3.77, 2, red, Entry
# 3.77, 2, red, Entry
# 3.77, 4, red, Entry
# 3.77, 4, red, Entry
# 3.77, 4, red, Entry
# 3.77, 4, red, Entry
# 3.77, 2, red, Entry
# 3.77, 2, red, Entry
# 3.77, 2, red, Entry
# 3.77, 2, red, Entry
# 3.82, 4, red, Entry
# 3.82, 4, red, Entry
# 3.82, 3, red, Entry
# 3.82, 4, red, Entry
# 3.82, 2, red, Entry
# 3.82, 4, red, Entry
# 3.82, 4, red, Entry
# 3.82, 4, red, Entry
# 3.82, 4, red, Entry
# 3.82, 2, red, Entry
# 3.82, 4, red, Entry
# 3.82, 2, red, Entry
# 3.82, 2, red, Entry
# 3.82, 1, red, Entry
# 3.82, 2, red, Entry
# 3.82, 4, blue, Entry
# 3.87, 4, red, Entry
# 3.87, 3, red, Entry
# 3.87, 4, red, Entry
# 3.87, 2, red, Entry
# 3.87, 2, red, Entry
# 3.87, 4, red, Entry
# 3.87, 2, red, Entry
# 3.87, 2, red, Entry
# 3.87, 4, red, Entry
# 3.87, 4, red, Entry
# 3.87, 2, red, Entry
# 3.87, 4, blue, Entry
# 3.87, 2, blue, Entry
# 3.91, 3, red, Entry
# 3.91, 4, red, Entry
# 3.91, 3, red, Entry
# 3.91, 4, red, Entry
# 3.91, 4, red, Entry
# 3.91, 4, red, Entry
# 3.91, 1, red, Entry
# 3.91, 4, red, Entry
# 3.91, 1, red, Entry
# 3.95, 3, red, Entry
# 3.95, 4, red, Entry
# 3.95, 3, red, Entry
# 3.95, 4, red, Entry
# 3.95, 4, red, Entry
# 3.95, 4, red, Entry
# 3.95, 4, red, Entry
# 3.95, 4, red, Entry
# 3.95, 4, red, Entry
# 3.95, 4, red, Entry
# 3.95, 4, blue, Entry
# 3.99, 4, red, Entry
# 3.99, 4, red, Entry
# 3.99, 3, red, Entry
# 3.99, 4, red, Entry
# 3.99, 4, red, Entry
# 3.99, 4, red, Entry
# 4.04, 3, red, Entry
# 4.04, 3, red, Entry
# 4.04, 4, red, Entry
# 4.04, 1, red, Entry
# 4.04, 4, red, Entry
# 4.08, 4, red, Entry
# 4.08, 4, red, Entry
# 4.08, 4, red, Entry
# 4.08, 2, red, Entry
# 4.12, 3, red, Entry
# 4.12, 1, red, Entry
# 4.15, 4, red, Entry
# 4.15, 2, red, Entry
# 4.20, 3, red, Entry
# 4.20, 3, red, Entry
# 4.20, 4, red, Entry
# 4.20, 4, blue, Entry
# 4.23, 3, red, Entry
# 4.23, 4, red, Entry
# 4.23, 3, red, Entry
# 4.23, 4, red, Entry
# 4.23, 3, red, Entry
# 4.23, 2, red, Entry
# 4.28, 3, red, Entry
# 4.28, 3, red, Entry
# 4.28, 3, red, Entry
# 4.28, 3, red, Entry
# 4.28, 1, red, Entry
# 4.28, 2, red, Entry
# 4.32, 3, red, Entry
# 4.32, 3, red, Entry
# 4.32, 3, red, Entry
# 4.32, 4, red, Entry
# 4.32, 1, red, Entry
# 4.32, 2, red, Entry
# 4.32, 1, red, Entry
# 4.36, 3, red, Entry
# 4.36, 2, red, Entry
# 4.40, 3, red, Entry
# 4.40, 1, red, Entry
# 4.43, 3, red, Entry
# 4.43, 3, red, Entry
# 4.48, 3, red, Entry
# 4.48, 2, red, Entry
# 4.52, 3, red, Entry
# 4.52, 3, red, Entry
# 4.52, 3, red, Entry
# 4.52, 2, red, Entry
# 4.52, 1, red, Entry
# 4.56, 3, red, Entry
# 4.56, 3, red, Entry
# 4.56, 1, red, Entry
# 4.59, 3, red, Entry
# 4.59, 3, red, Entry
# 4.63, 3, red, Entry
# 4.63, 2, red, Entry
# 4.63, 2, red, Entry
# 4.67, 3, red, Entry
# 4.67, 3, red, Entry
# 4.67, 3, red, Entry
# 4.67, 3, red, Entry
# 4.71, 3, red, Entry
# 4.71, 3, red, Entry
# 4.71, 3, red, Entry
# 4.75, 3, red, Entry
# 4.75, 3, red, Entry
# 4.75, 3, red, Entry
# 4.75, 1, red, Entry
# 4.79, 3, red, Entry
# 4.79, 3, red, Entry
# 4.79, 1, red, Entry
# 4.79, 4, blue, Entry
# 4.83, 3, red, Entry
# 4.83, 1, red, Entry
# 4.87, 3, red, Entry
# 4.87, 1, red, Entry
# 4.91, 3, red, Entry
# 4.91, 4, red, Entry
# 4.91, 4, red, Entry
# 4.91, 1, red, Entry
# 4.95, 3, red, Entry
# 4.95, 4, red, Entry
# 4.95, 4, red, Entry
# 4.95, 2, red, Entry
# 4.98, 2, red, Entry
# 5.02, 3, red, Entry
# 5.02, 4, red, Entry
# 5.02, 4, red, Entry
# 5.02, 1, red, Entry
# 5.05, 4, red, Entry
# 5.05, 2, red, Entry
# 5.09, 3, red, Entry
# 5.09, 4, red, Entry
# 5.09, 4, red, Entry
# 5.16, 4, red, Entry
# 5.16, 2, red, Entry
# 5.20, 3, red, Entry
# 5.20, 4, red, Entry
# 5.20, 2, red, Entry
# 5.24, 1, red, Entry
# 5.24, 2, red, Entry
# 5.24, 4, blue, Entry
# 5.24, 2, blue, Entry
# 5.28, 3, red, Entry
# 5.28, 3, red, Entry
# 5.28, 4, red, Entry
# 5.28, 1, red, Entry
# 5.28, 2, red, Entry
# 5.32, 4, red, Entry
# 5.32, 2, red, Entry
# 5.36, 4, red, Entry
# 5.36, 1, red, Entry
# 5.36, 2, red, Entry
# 5.36, 1, red, Entry
# 5.40, 4, red, Entry
# 5.40, 4, red, Entry
# 5.40, 3, red, Entry
# 5.40, 1, red, Entry
# 5.40, 4, red, Entry
# 5.44, 3, red, Entry
# 5.44, 4, red, Entry
# 5.44, 4, red, Entry
# 5.44, 4, red, Entry
# 5.44, 4, red, Entry
# 5.44, 4, red, Entry
# 5.44, 3, red, Entry
# 5.44, 4, red, Entry
# 5.44, 1, red, Entry
# 5.44, 2, red, Entry
# 5.49, 4, red, Entry
# 5.49, 4, red, Entry
# 5.49, 4, red, Entry
# 5.49, 4, red, Entry
# 5.49, 4, red, Entry
# 5.49, 4, red, Entry
# 5.49, 4, red, Entry
# 5.49, 3, red, Entry
# 5.49, 4, red, Entry
# 5.49, 1, red, Entry
# 5.52, 4, red, Entry
# 5.52, 4, red, Entry
# 5.52, 4, red, Entry
# 5.52, 3, red, Entry
# 5.52, 4, red, Entry
# 5.52, 4, red, Entry
# 5.52, 4, red, Entry
# 5.52, 4, red, Entry
# 5.52, 4, red, Entry
# 5.52, 4, red, Entry
# 5.52, 3, red, Entry
# 5.52, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 3, red, Entry
# 5.56, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 4, red, Entry
# 5.56, 1, red, Entry
# 5.56, 4, blue, Entry
# 5.60, 4, red, Entry
# 5.60, 4, red, Entry
# 5.60, 3, red, Entry
# 5.60, 4, red, Entry
# 5.60, 4, red, Entry
# 5.60, 4, red, Entry
# 5.60, 3, red, Entry
# 5.60, 4, red, Entry
# 5.60, 1, red, Entry
# 5.64, 4, red, Entry
# 5.64, 4, red, Entry
# 5.64, 3, red, Entry
# 5.64, 4, red, Entry
# 5.64, 4, red, Entry
# 5.64, 4, red, Entry
# 5.64, 4, red, Entry
# 5.64, 4, red, Entry
# 5.64, 4, red, Entry
# 5.64, 3, red, Entry
# 5.64, 4, red, Entry
# 5.68, 4, red, Entry
# 5.68, 3, red, Entry
# 5.68, 4, red, Entry
# 5.68, 4, red, Entry
# 5.68, 4, red, Entry
# 5.68, 4, red, Entry
# 5.68, 4, red, Entry
# 5.68, 4, red, Entry
# 5.68, 4, red, Entry
# 5.68, 1, red, Entry
# 5.68, 4, red, Entry
# 5.68, 2, red, Entry
# 5.72, 3, red, Entry
# 5.72, 4, red, Entry
# 5.72, 3, red, Entry
# 5.72, 4, red, Entry
# 5.72, 4, red, Entry
# 5.72, 4, red, Entry
# 5.72, 4, red, Entry
# 5.72, 3, red, Entry
# 5.76, 4, red, Entry
# 5.76, 4, red, Entry
# 5.76, 4, red, Entry
# 5.76, 4, red, Entry
# 5.76, 4, red, Entry
# 5.76, 3, red, Entry
# 5.76, 4, red, Entry
# 5.76, 1, red, Entry
# 5.81, 3, red, Entry
# 5.81, 4, red, Entry
# 5.81, 4, red, Entry
# 5.81, 4, red, Entry
# 5.81, 4, red, Entry
# 5.81, 4, red, Entry
# 5.81, 4, red, Entry
# 5.81, 3, red, Entry
# 5.81, 4, red, Entry
# 5.81, 2, red, Entry
# 5.81, 1, red, Entry
# 5.85, 4, red, Entry
# 5.85, 4, red, Entry
# 5.85, 4, red, Entry
# 5.85, 4, red, Entry
# 5.85, 3, red, Entry
# 5.85, 2, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 4, red, Entry
# 5.89, 2, red, Entry
# 5.89, 1, red, Entry
# 5.89, 2, red, Entry
# 5.93, 3, red, Entry
# 5.93, 4, red, Entry
# 5.93, 4, red, Entry
# 5.93, 4, red, Entry
# 5.93, 4, red, Entry
# 5.93, 4, red, Entry
# 5.93, 4, red, Entry
# 5.93, 4, red, Entry
# 5.93, 3, red, Entry
# 5.93, 1, red, Entry
# 5.93, 1, red, Entry
# 5.98, 3, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 4, red, Entry
# 5.98, 3, red, Entry
# 5.98, 4, red, Entry
# 5.98, 1, red, Entry
# 6.01, 3, red, Entry
# 6.01, 4, red, Entry
# 6.01, 4, red, Entry
# 6.01, 4, red, Entry
# 6.01, 4, red, Entry
# 6.01, 4, red, Entry
# 6.01, 4, red, Entry
# 6.01, 3, red, Entry
# 6.01, 2, red, Entry
# 6.06, 4, red, Entry
# 6.06, 3, red, Entry
# 6.06, 4, red, Entry
# 6.06, 4, red, Entry
# 6.06, 4, red, Entry
# 6.06, 4, red, Entry
# 6.06, 4, red, Entry
# 6.06, 3, red, Entry
# 6.10, 4, red, Entry
# 6.10, 3, red, Entry
# 6.10, 4, red, Entry
# 6.10, 4, red, Entry
# 6.10, 4, red, Entry
# 6.10, 4, red, Entry
# 6.10, 4, red, Entry
# 6.10, 4, red, Entry
# 6.10, 4, red, Entry
# 6.10, 4, red, Entry
# 6.10, 1, red, Entry
# 6.15, 4, red, Entry
# 6.15, 4, red, Entry
# 6.15, 3, red, Entry
# 6.15, 4, red, Entry
# 6.15, 4, red, Entry
# 6.15, 4, red, Entry
# 6.15, 4, red, Entry
# 6.15, 4, red, Entry
# 6.15, 4, red, Entry
# 6.15, 1, red, Entry
# 6.19, 4, red, Entry
# 6.19, 4, red, Entry
# 6.19, 3, red, Entry
# 6.19, 3, red, Entry
# 6.19, 4, red, Entry
# 6.19, 4, red, Entry
# 6.19, 4, red, Entry
# 6.19, 3, red, Entry
# 6.23, 4, red, Entry
# 6.23, 4, red, Entry
# 6.23, 4, red, Entry
# 6.23, 4, red, Entry
# 6.23, 4, red, Entry
# 6.23, 3, red, Entry
# 6.23, 4, red, Entry
# 6.23, 4, red, Entry
# 6.23, 4, red, Entry
# 6.23, 2, red, Entry
# 6.23, 1, red, Entry
# 6.23, 2, blue, Entry
# 6.27, 3, red, Entry
# 6.27, 4, red, Entry
# 6.27, 3, red, Entry
# 6.27, 4, red, Entry
# 6.27, 4, red, Entry
# 6.27, 3, red, Entry
# 6.27, 4, red, Entry
# 6.27, 3, red, Entry
# 6.27, 4, red, Entry
# 6.27, 4, red, Entry
# 6.27, 4, red, Entry
# 6.27, 4, red, Entry
# 6.27, 1, red, Entry
# 6.27, 2, blue, Entry
# 6.32, 3, red, Entry
# 6.32, 3, red, Entry
# 6.32, 4, red, Entry
# 6.32, 3, red, Entry
# 6.32, 4, red, Entry
# 6.32, 4, red, Entry
# 6.32, 4, red, Entry
# 6.32, 4, red, Entry
# 6.32, 4, red, Entry
# 6.32, 4, red, Entry
# 6.32, 3, red, Entry
# 6.36, 4, red, Entry
# 6.36, 3, red, Entry
# 6.36, 4, red, Entry
# 6.36, 4, red, Entry
# 6.36, 4, red, Entry
# 6.36, 4, red, Entry
# 6.36, 4, red, Entry
# 6.36, 4, red, Entry
# 6.36, 3, red, Entry
# 6.41, 3, red, Entry
# 6.41, 4, red, Entry
# 6.41, 3, red, Entry
# 6.41, 4, red, Entry
# 6.41, 4, red, Entry
# 6.41, 4, red, Entry
# 6.41, 4, red, Entry
# 6.41, 4, red, Entry
# 6.41, 4, red, Entry
# 6.41, 4, red, Entry
# 6.41, 4, red, Entry
# 6.41, 3, red, Entry
# 6.41, 1, red, Entry
# 6.41, 2, red, Entry
# 6.41, 1, red, Entry
# 6.45, 3, red, Entry
# 6.45, 4, red, Entry
# 6.45, 3, red, Entry
# 6.45, 4, red, Entry
# 6.45, 4, red, Entry
# 6.45, 4, red, Entry
# 6.45, 4, red, Entry
# 6.45, 4, red, Entry
# 6.45, 4, red, Entry
# 6.45, 4, red, Entry
# 6.45, 3, red, Entry
# 6.49, 3, red, Entry
# 6.49, 3, red, Entry
# 6.49, 4, red, Entry
# 6.49, 4, red, Entry
# 6.49, 4, red, Entry
# 6.49, 4, red, Entry
# 6.49, 4, red, Entry
# 6.49, 4, red, Entry
# 6.49, 4, red, Entry
# 6.49, 3, red, Entry
# 6.49, 2, red, Entry
# 6.53, 3, red, Entry
# 6.53, 4, red, Entry
# 6.53, 4, red, Entry
# 6.53, 4, red, Entry
# 6.53, 4, red, Entry
# 6.53, 4, red, Entry
# 6.53, 4, red, Entry
# 6.53, 4, red, Entry
# 6.53, 3, red, Entry
# 6.53, 2, red, Entry
# 6.57, 4, red, Entry
# 6.57, 4, red, Entry
# 6.57, 4, red, Entry
# 6.57, 4, red, Entry
# 6.57, 4, red, Entry
# 6.57, 4, red, Entry
# 6.57, 4, red, Entry
# 6.57, 3, red, Entry
# 6.57, 2, red, Entry
# 6.57, 1, red, Entry
# 6.61, 4, red, Entry
# 6.61, 3, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 4, red, Entry
# 6.61, 3, red, Entry
# 6.61, 1, red, Entry
# 6.61, 1, red, Entry
# 6.65, 4, red, Entry
# 6.65, 4, red, Entry
# 6.65, 4, red, Entry
# 6.65, 4, red, Entry
# 6.65, 4, red, Entry
# 6.65, 4, red, Entry
# 6.65, 3, red, Entry
# 6.65, 1, red, Entry
# 6.65, 2, red, Entry
# 6.65, 1, red, Entry
# 6.70, 3, red, Entry
# 6.70, 4, red, Entry
# 6.70, 4, red, Entry
# 6.70, 4, red, Entry
# 6.70, 4, red, Entry
# 6.70, 4, red, Entry
# 6.70, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 4, red, Entry
# 6.74, 2, red, Entry
# 6.78, 3, red, Entry
# 6.78, 3, red, Entry
# 6.78, 4, red, Entry
# 6.78, 4, red, Entry
# 6.78, 4, red, Entry
# 6.78, 4, red, Entry
# 6.78, 4, red, Entry
# 6.78, 4, red, Entry
# 6.78, 4, red, Entry
# 6.78, 4, red, Entry
# 6.78, 2, red, Entry
# 6.82, 4, red, Entry
# 6.82, 4, red, Entry
# 6.82, 4, red, Entry
# 6.82, 4, red, Entry
# 6.87, 3, red, Entry
# 6.87, 3, red, Entry
# 6.87, 4, red, Entry
# 6.87, 4, red, Entry
# 6.87, 4, red, Entry
# 6.87, 4, red, Entry
# 6.87, 4, red, Entry
# 6.87, 4, red, Entry
# 6.87, 3, red, Entry
# 6.87, 4, red, Entry
# 6.91, 4, red, Entry
# 6.91, 3, red, Entry
# 6.91, 4, red, Entry
# 6.91, 4, red, Entry
# 6.91, 4, red, Entry
# 6.91, 3, red, Entry
# 6.91, 2, red, Entry
# 6.95, 3, red, Entry
# 6.95, 3, red, Entry
# 6.95, 4, red, Entry
# 6.95, 4, red, Entry
# 6.95, 4, red, Entry
# 6.95, 4, red, Entry
# 6.95, 3, red, Entry
# 6.95, 2, red, Entry
# 6.99, 3, red, Entry
# 6.99, 4, red, Entry
# 6.99, 3, red, Entry
# 6.99, 4, red, Entry
# 6.99, 4, red, Entry
# 6.99, 4, red, Entry
# 6.99, 4, red, Entry
# 6.99, 2, red, Entry
# 7.03, 4, red, Entry
# 7.03, 4, red, Entry
# 7.03, 3, red, Entry
# 7.03, 4, red, Entry
# 7.03, 4, red, Entry
# 7.03, 4, red, Entry
# 7.03, 4, red, Entry
# 7.03, 4, red, Entry
# 7.03, 3, red, Entry
# 7.07, 4, red, Entry
# 7.07, 3, red, Entry
# 7.07, 4, red, Entry
# 7.07, 4, red, Entry
# 7.07, 4, red, Entry
# 7.07, 4, red, Entry
# 7.07, 4, red, Entry
# 7.07, 4, red, Entry
# 7.07, 4, red, Entry
# 7.07, 3, red, Entry
# 7.11, 3, red, Entry
# 7.11, 4, red, Entry
# 7.11, 4, red, Entry
# 7.11, 4, red, Entry
# 7.11, 4, red, Entry
# 7.11, 3, red, Entry
# 7.15, 4, red, Entry
# 7.15, 4, red, Entry
# 7.15, 3, red, Entry
# 7.15, 4, red, Entry
# 7.15, 4, red, Entry
# 7.15, 4, red, Entry
# 7.15, 4, red, Entry
# 7.15, 2, red, Entry
# 7.18, 4, red, Entry
# 7.18, 3, red, Entry
# 7.18, 4, red, Entry
# 7.18, 3, red, Entry
# 7.18, 1, red, Entry
# 7.18, 4, red, Entry
# 7.18, 4, red, Entry
# 7.18, 4, red, Entry
# 7.18, 4, red, Entry
# 7.22, 4, red, Entry
# 7.22, 3, red, Entry
# 7.22, 2, red, Entry
# 7.22, 2, red, Entry
# 7.22, 4, red, Entry
# 7.22, 4, red, Entry
# 7.22, 4, red, Entry
# 7.26, 4, red, Entry
# 7.26, 3, red, Entry
# 7.26, 3, red, Entry
# 7.30, 3, red, Entry
# 7.34, 4, red, Entry
# 7.34, 2, red, Entry
# 7.38, 1, red, Entry
# 7.42, 3, red, Entry
# 7.46, 3, red, Entry
# 7.46, 1, red, Entry
# 7.49, 3, red, Entry
# 7.49, 1, red, Entry
# 7.49, 1, red, Entry
# 7.49, 1, red, Entry
# 7.49, 2, blue, Entry
# 7.53, 3, red, Entry
# 7.53, 1, red, Entry
# 7.53, 1, red, Entry
# 7.53, 1, red, Entry
# 7.57, 3, red, Entry
# 7.57, 1, red, Entry
# 7.61, 4, red, Entry
# 7.61, 3, red, Entry
# 7.61, 3, red, Entry
# 7.61, 2, red, Entry
# 7.61, 2, red, Entry
# 7.65, 4, red, Entry
# 7.65, 3, red, Entry
# 7.70, 4, red, Entry
# 7.70, 4, red, Entry
# 7.70, 3, red, Entry
# 7.70, 1, red, Entry
# 7.74, 4, red, Entry
# 7.74, 3, red, Entry
# 7.74, 2, red, Entry
# 7.78, 3, red, Entry
# 7.78, 4, red, Entry
# 7.78, 3, red, Entry
# 7.78, 2, red, Entry
# 7.78, 4, blue, Entry
# 7.82, 4, red, Entry
# 7.82, 3, red, Entry
# 7.82, 4, red, Entry
# 7.82, 3, red, Entry
# 7.82, 2, red, Entry
# 7.82, 4, blue, Entry
# 7.82, 2, blue, Entry
# 7.86, 3, red, Entry
# 7.86, 3, red, Entry
# 7.86, 1, red, Entry
# 7.90, 4, red, Entry
# 7.90, 3, red, Entry
# 7.90, 2, red, Entry
# 7.94, 3, red, Entry
# 7.94, 3, red, Entry
# 7.94, 2, red, Entry
# 7.97, 3, red, Entry
# 7.97, 4, red, Entry
# 7.97, 3, red, Entry
# 7.97, 2, red, Entry
# 8.01, 3, red, Entry
# 8.01, 3, red, Entry
# 8.01, 1, red, Entry
# 8.05, 3, red, Entry
# 8.05, 4, red, Entry
# 8.05, 4, red, Entry
# 8.05, 1, red, Entry
# 8.05, 1, red, Entry
# 8.09, 3, red, Entry
# 8.09, 4, red, Entry
# 8.09, 4, red, Entry
# 8.09, 1, red, Entry
# 8.13, 3, red, Entry
# 8.13, 4, red, Entry
# 8.13, 1, red, Entry
# 8.13, 2, red, Entry
# 8.13, 1, red, Entry
# 8.17, 3, red, Entry
# 8.17, 4, red, Entry
# 8.17, 1, red, Entry
# 8.17, 1, red, Entry
# 8.21, 3, red, Entry
# 8.21, 4, red, Entry
# 8.21, 4, red, Entry
# 8.21, 2, red, Entry
# 8.21, 1, red, Entry
# 8.25, 3, red, Entry
# 8.25, 4, red, Entry
# 8.25, 4, red, Entry
# 8.30, 3, red, Entry
# 8.30, 4, red, Entry
# 8.30, 2, red, Entry
# 8.30, 1, red, Entry
# 8.34, 4, red, Entry
# 8.34, 3, red, Entry
# 8.38, 4, red, Entry
# 8.38, 3, red, Entry
# 8.38, 4, red, Entry
# 8.38, 2, red, Entry
# 8.38, 2, red, Entry
# 8.42, 3, red, Entry
# 8.42, 4, red, Entry
# 8.42, 3, red, Entry
# 8.42, 4, red, Entry
# 8.42, 1, red, Entry
# 8.42, 2, red, Entry
# 8.42, 2, blue, Entry
# 8.45, 3, red, Entry
# 8.45, 4, red, Entry
# 8.45, 3, red, Entry
# 8.45, 4, red, Entry
# 8.45, 2, red, Entry
# 8.49, 4, red, Entry
# 8.49, 4, red, Entry
# 8.49, 4, red, Entry
# 8.49, 3, red, Entry
# 8.53, 4, red, Entry
# 8.53, 4, red, Entry
# 8.53, 2, red, Entry
# 8.57, 3, red, Entry
# 8.57, 4, red, Entry
# 8.61, 3, red, Entry
# 8.61, 4, red, Entry
# 8.61, 2, red, Entry
# 8.61, 1, red, Entry
# 8.61, 1, red, Entry
# 8.61, 2, red, Entry
# 8.65, 3, red, Entry
# 8.65, 4, red, Entry
# 8.65, 3, red, Entry
# 8.65, 4, red, Entry
# 8.65, 1, red, Entry
# 8.69, 3, red, Entry
# 8.69, 4, red, Entry
# 8.69, 4, red, Entry
# 8.69, 2, red, Entry
# 8.73, 3, red, Entry
# 8.73, 4, red, Entry
# 8.73, 4, red, Entry
# 8.77, 3, red, Entry
# 8.81, 3, red, Entry
# 8.81, 2, red, Entry
# 8.81, 4, blue, Entry
# 8.85, 4, red, Entry
# 8.85, 3, red, Entry
# 8.85, 4, blue, Entry
# 8.89, 3, red, Entry
# 8.89, 4, red, Entry
# 8.89, 2, red, Entry
# 8.97, 3, red, Entry
# 9.01, 3, red, Entry
# 9.01, 4, red, Entry
# 9.01, 3, red, Entry
# 9.05, 3, red, Entry
# 9.09, 3, red, Entry
# 9.09, 4, red, Entry
# 9.09, 3, red, Entry
# 9.09, 1, red, Entry
# 9.09, 2, red, Entry
# 9.13, 3, red, Entry
# 9.13, 3, red, Entry
# 9.13, 1, red, Entry
# 9.13, 2, red, Entry
# 9.21, 3, red, Entry
# 9.21, 3, red, Entry
# 9.21, 1, red, Entry
# 9.26, 3, red, Entry
# 9.26, 3, red, Entry
# 9.30, 3, red, Entry
# 9.30, 3, red, Entry
# 9.30, 4, red, Entry
# 9.34, 3, red, Entry
# 9.34, 4, red, Entry
# 9.38, 3, red, Entry
# 9.38, 4, red, Entry
# 9.38, 3, red, Entry
# 9.38, 2, blue, Entry
# 9.41, 3, red, Entry
# 9.41, 3, red, Entry
# 9.45, 3, red, Entry
# 9.45, 1, red, Entry
# 9.45, 4, blue, Entry
# 9.49, 3, red, Entry
# 9.49, 2, red, Entry
# 9.49, 4, blue, Entry
# 9.53, 3, red, Entry
# 9.53, 3, red, Entry
# 9.53, 2, red, Entry
# 9.53, 4, blue, Entry
# 9.57, 3, red, Entry
# 9.57, 4, red, Entry
# 9.61, 3, red, Entry
# 9.61, 3, red, Entry
# 9.61, 3, red, Entry
# 9.61, 1, red, Entry
# 9.65, 3, red, Entry
# 9.65, 3, red, Entry
# 9.65, 1, red, Entry
# 9.65, 1, red, Entry
# 9.65, 2, red, Entry
# 9.69, 4, red, Entry
# 9.69, 3, red, Entry
# 9.69, 2, red, Entry
# 9.73, 3, red, Entry
# 9.73, 3, red, Entry
# 9.73, 3, red, Entry
# 9.73, 1, red, Entry
# 9.77, 3, red, Entry
# 9.77, 4, red, Entry
# 9.85, 3, red, Entry
# 9.85, 4, red, Entry
# 9.85, 2, red, Entry
# 9.85, 1, red, Entry
# 9.85, 4, blue, Entry
# 9.88, 3, red, Entry
# 9.88, 4, red, Entry
# 9.91, 3, red, Entry
# 9.91, 4, red, Entry
# 9.91, 2, red, Entry
# 9.95, 3, red, Entry
# 9.95, 3, red, Entry
# 9.95, 4, red, Entry
# 9.99, 4, red, Entry
# 9.99, 1, red, Entry
# 10.03, 3, red, Entry
# 10.03, 3, red, Entry
# 10.03, 3, red, Entry
# 10.03, 4, red, Entry
# 10.07, 4, red, Entry
# 10.10, 3, red, Entry
# 10.10, 4, red, Entry
# 10.10, 4, red, Entry
# 10.10, 4, red, Entry
# 10.10, 2, red, Entry
# 10.10, 1, red, Entry
# 10.14, 3, red, Entry
# 10.14, 3, red, Entry
# 10.14, 3, red, Entry
# 10.14, 4, red, Entry
# 10.18, 3, red, Entry
# 10.18, 3, red, Entry
# 10.18, 4, red, Entry
# 10.18, 4, red, Entry
# 10.18, 2, red, Entry
# 10.22, 3, red, Entry
# 10.22, 4, red, Entry
# 10.25, 3, red, Entry
# 10.25, 4, red, Entry
# 10.25, 2, red, Entry
# 10.29, 3, red, Entry
# 10.29, 4, red, Entry
# 10.29, 4, red, Entry
# 10.32, 3, red, Entry
# 10.32, 4, red, Entry
# 10.32, 2, red, Entry
# 10.32, 2, red, Entry
# 10.36, 3, red, Entry
# 10.36, 4, red, Entry
# 10.36, 3, red, Entry
# 10.36, 4, red, Entry
# 10.36, 1, red, Entry
# 10.36, 2, red, Entry
# 10.40, 3, red, Entry
# 10.40, 3, red, Entry
# 10.40, 4, red, Entry
# 10.40, 4, red, Entry
# 10.40, 2, red, Entry
# 10.44, 3, red, Entry
# 10.44, 2, red, Entry
# 10.44, 1, red, Entry
# 10.48, 3, red, Entry
# 10.52, 3, red, Entry
# 10.52, 4, red, Entry
# 10.52, 1, red, Entry
# 10.56, 4, red, Entry
# 10.56, 2, red, Entry
# 10.56, 1, red, Entry
# 10.60, 3, red, Entry
# 10.60, 3, red, Entry
# 10.60, 2, red, Entry
# 10.60, 4, blue, Entry
# 10.63, 3, red, Entry
# 10.63, 3, red, Entry
# 10.63, 4, blue, Entry
# 10.67, 3, red, Entry
# 10.67, 3, red, Entry
# 10.67, 4, red, Entry
# 10.67, 3, red, Entry
# 10.67, 4, blue, Entry
# 10.71, 3, red, Entry
# 10.71, 4, red, Entry
# 10.71, 1, red, Entry
# 10.71, 4, blue, Entry
# 10.75, 3, red, Entry
# 10.75, 3, red, Entry
# 10.75, 4, red, Entry
# 10.75, 2, red, Entry
# 10.79, 4, red, Entry
# 10.79, 3, red, Entry
# 10.79, 1, red, Entry
# 10.79, 2, red, Entry
# 10.83, 3, red, Entry
# 10.83, 4, red, Entry
# 10.83, 3, red, Entry
# 10.83, 4, red, Entry
# 10.83, 1, red, Entry
# 10.86, 3, red, Entry
# 10.86, 4, red, Entry
# 10.86, 3, red, Entry
# 10.86, 2, red, Entry
# 10.90, 3, red, Entry
# 10.90, 4, red, Entry
# 10.90, 4, red, Entry
# 10.90, 3, red, Entry
# 10.90, 2, red, Entry
# 10.94, 3, red, Entry
# 10.94, 4, red, Entry
# 10.94, 4, red, Entry
# 10.94, 3, red, Entry
# 10.98, 4, red, Entry
# 10.98, 3, red, Entry
# 10.98, 1, red, Entry
# 10.98, 4, red, Entry
# 10.98, 2, red, Entry
# 11.02, 3, red, Entry
# 11.06, 4, red, Entry
# 11.06, 3, red, Entry
# 11.06, 3, red, Entry
# 11.09, 4, red, Entry
# 11.09, 3, red, Entry
# 11.09, 3, red, Entry
# 11.13, 4, red, Entry
# 11.13, 4, red, Entry
# 11.13, 3, red, Entry
# 11.13, 4, red, Entry
# 11.13, 1, red, Entry
# 11.17, 4, red, Entry
# 11.17, 3, red, Entry
# 11.17, 4, red, Entry
# 11.17, 4, red, Entry
# 11.17, 3, red, Entry
# 11.17, 2, red, Entry
# 11.21, 4, red, Entry
# 11.21, 4, red, Entry
# 11.21, 4, red, Entry
# 11.21, 4, red, Entry
# 11.21, 4, red, Entry
# 11.21, 3, red, Entry
# 11.21, 2, red, Entry
# 11.21, 4, green, Entry
# 11.24, 4, red, Entry
# 11.24, 4, red, Entry
# 11.24, 4, red, Entry
# 11.24, 4, red, Entry
# 11.24, 4, red, Entry
# 11.24, 4, red, Entry
# 11.24, 3, red, Entry
# 11.24, 4, red, Entry
# 11.24, 4, red, Entry
# 11.24, 2, red, Entry
# 11.24, 2, red, Entry
# 11.28, 4, red, Entry
# 11.28, 4, red, Entry
# 11.28, 4, red, Entry
# 11.28, 4, red, Entry
# 11.28, 4, red, Entry
# 11.28, 3, red, Entry
# 11.28, 4, red, Entry
# 11.28, 2, red, Entry
# 11.28, 2, red, Entry
# 11.28, 2, red, Entry
# 11.28, 4, red, Entry
# 11.28, 2, red, Entry
# 11.32, 4, red, Entry
# 11.32, 4, red, Entry
# 11.32, 4, red, Entry
# 11.32, 4, red, Entry
# 11.32, 4, red, Entry
# 11.32, 2, red, Entry
# 11.32, 2, red, Entry
# 11.32, 1, red, Entry
# 11.32, 2, red, Entry
# 11.32, 4, red, Entry
# 11.32, 4, red, Entry
# 11.32, 4, red, Entry
# 11.32, 2, red, Entry
# 11.32, 1, red, Entry
# 11.37, 3, red, Entry
# 11.37, 4, red, Entry
# 11.37, 3, red, Entry
# 11.37, 4, red, Entry
# 11.37, 4, red, Entry
# 11.37, 2, red, Entry
# 11.37, 2, red, Entry
# 11.37, 2, red, Entry
# 11.37, 2, red, Entry
# 11.37, 2, red, Entry
# 11.37, 2, red, Entry
# 11.37, 2, red, Entry
# 11.41, 4, red, Entry
# 11.41, 4, red, Entry
# 11.41, 2, red, Entry
# 11.41, 2, red, Entry
# 11.41, 2, red, Entry
# 11.41, 2, red, Entry
# 11.41, 1, red, Entry
# 11.45, 3, red, Entry
# 11.45, 4, red, Entry
# 11.45, 4, red, Entry
# 11.45, 3, red, Entry
# 11.45, 2, red, Entry
# 11.45, 2, red, Entry
# 11.45, 2, red, Entry
# 11.45, 4, red, Entry
# 11.45, 4, red, Entry
# 11.45, 4, red, Entry
# 11.45, 2, red, Entry
# 11.45, 2, red, Entry
# 11.45, 1, red, Entry
# 11.50, 3, red, Entry
# 11.50, 4, red, Entry
# 11.50, 2, red, Entry
# 11.50, 2, red, Entry
# 11.50, 2, red, Entry
# 11.50, 4, red, Entry
# 11.50, 4, red, Entry
# 11.50, 4, red, Entry
# 11.50, 4, red, Entry
# 11.50, 2, red, Entry
# 11.50, 2, red, Entry
# 11.50, 1, red, Entry
# 11.50, 2, blue, Entry
# 11.54, 3, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 2, red, Entry
# 11.54, 2, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 4, red, Entry
# 11.54, 2, red, Entry
# 11.54, 2, red, Entry
# 11.54, 2, red, Entry
# 11.54, 2, red, Entry
# 11.54, 2, blue, Entry
# 11.58, 4, red, Entry
# 11.58, 3, red, Entry
# 11.58, 4, red, Entry
# 11.58, 4, red, Entry
# 11.58, 2, red, Entry
# 11.58, 2, red, Entry
# 11.58, 2, red, Entry
# 11.58, 4, red, Entry
# 11.58, 4, red, Entry
# 11.58, 4, red, Entry
# 11.58, 4, red, Entry
# 11.58, 2, red, Entry
# 11.58, 2, red, Entry
# 11.58, 2, blue, Entry
# 11.63, 3, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 2, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 4, red, Entry
# 11.63, 2, red, Entry
# 11.63, 2, red, Entry
# 11.63, 2, red, Entry
# 11.67, 4, red, Entry
# 11.67, 3, red, Entry
# 11.67, 3, red, Entry
# 11.67, 4, red, Entry
# 11.67, 2, red, Entry
# 11.67, 2, red, Entry
# 11.67, 2, red, Entry
# 11.67, 4, red, Entry
# 11.67, 4, red, Entry
# 11.67, 4, red, Entry
# 11.67, 4, red, Entry
# 11.67, 4, red, Entry
# 11.67, 4, red, Entry
# 11.67, 2, red, Entry
# 11.67, 2, red, Entry
# 11.67, 2, red, Entry
# 11.67, 4, blue, Entry
# 11.71, 4, red, Entry
# 11.71, 3, red, Entry
# 11.71, 4, red, Entry
# 11.71, 3, red, Entry
# 11.71, 4, red, Entry
# 11.71, 3, red, Entry
# 11.71, 2, red, Entry
# 11.71, 2, red, Entry
# 11.71, 2, red, Entry
# 11.71, 2, red, Entry
# 11.71, 4, red, Entry
# 11.71, 4, red, Entry
# 11.71, 4, red, Entry
# 11.71, 4, red, Entry
# 11.71, 2, red, Entry
# 11.71, 2, red, Entry
# 11.71, 2, red, Entry
# 11.75, 4, red, Entry
# 11.75, 3, red, Entry
# 11.75, 4, red, Entry
# 11.75, 1, red, Entry
# 11.75, 2, red, Entry
# 11.75, 2, red, Entry
# 11.75, 4, red, Entry
# 11.75, 4, red, Entry
# 11.75, 4, red, Entry
# 11.75, 4, red, Entry
# 11.75, 4, red, Entry
# 11.75, 4, red, Entry
# 11.75, 2, red, Entry
# 11.75, 2, red, Entry
# 11.75, 2, red, Entry
# 11.75, 2, red, Entry
# 11.75, 2, red, Entry
# 11.75, 4, blue, Entry
# 11.80, 4, red, Entry
# 11.80, 4, red, Entry
# 11.80, 3, red, Entry
# 11.80, 4, red, Entry
# 11.80, 1, red, Entry
# 11.80, 2, red, Entry
# 11.80, 2, red, Entry
# 11.80, 2, red, Entry
# 11.80, 2, red, Entry
# 11.80, 4, red, Entry
# 11.80, 4, red, Entry
# 11.80, 2, red, Entry
# 11.80, 2, red, Entry
# 11.80, 2, red, Entry
# 11.80, 2, red, Entry
# 11.80, 4, blue, Entry
# 11.84, 3, red, Entry
# 11.84, 3, red, Entry
# 11.84, 4, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 4, red, Entry
# 11.84, 4, red, Entry
# 11.84, 4, red, Entry
# 11.84, 4, red, Entry
# 11.84, 4, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 2, red, Entry
# 11.84, 4, blue, Entry
# 11.89, 3, red, Entry
# 11.89, 3, red, Entry
# 11.89, 4, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 4, red, Entry
# 11.89, 4, red, Entry
# 11.89, 2, red, Entry
# 11.89, 4, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 2, red, Entry
# 11.89, 1, red, Entry
# 11.89, 4, blue, Entry
# 11.93, 3, red, Entry
# 11.93, 4, red, Entry
# 11.93, 4, red, Entry
# 11.93, 2, red, Entry
# 11.93, 2, red, Entry
# 11.93, 2, red, Entry
# 11.93, 2, red, Entry
# 11.93, 4, red, Entry
# 11.93, 4, red, Entry
# 11.93, 4, red, Entry
# 11.93, 4, red, Entry
# 11.93, 4, red, Entry
# 11.93, 2, red, Entry
# 11.93, 4, red, Entry
# 11.93, 2, red, Entry
# 11.93, 2, red, Entry
# 11.98, 4, red, Entry
# 11.98, 3, red, Entry
# 11.98, 1, red, Entry
# 11.98, 2, red, Entry
# 11.98, 2, red, Entry
# 11.98, 2, red, Entry
# 11.98, 2, red, Entry
# 11.98, 4, red, Entry
# 11.98, 4, red, Entry
# 11.98, 2, red, Entry
# 11.98, 2, red, Entry
# 11.98, 4, red, Entry
# 11.98, 2, red, Entry
# 11.98, 2, red, Entry
# 11.98, 4, blue, Entry
# 11.98, 2, green, Entry
# 12.02, 4, red, Entry
# 12.02, 3, red, Entry
# 12.02, 4, red, Entry
# 12.02, 2, red, Entry
# 12.02, 2, red, Entry
# 12.02, 1, red, Entry
# 12.02, 2, red, Entry
# 12.02, 4, red, Entry
# 12.02, 4, red, Entry
# 12.02, 4, red, Entry
# 12.02, 4, red, Entry
# 12.02, 2, red, Entry
# 12.02, 2, red, Entry
# 12.02, 2, red, Entry
# 12.02, 2, red, Entry
# 12.02, 4, blue, Entry
# 12.07, 3, red, Entry
# 12.07, 3, red, Entry
# 12.07, 4, red, Entry
# 12.07, 2, red, Entry
# 12.07, 2, red, Entry
# 12.07, 2, red, Entry
# 12.07, 2, red, Entry
# 12.07, 2, red, Entry
# 12.07, 4, red, Entry
# 12.07, 4, red, Entry
# 12.07, 4, red, Entry
# 12.07, 4, red, Entry
# 12.07, 4, red, Entry
# 12.07, 4, red, Entry
# 12.07, 2, red, Entry
# 12.07, 2, red, Entry
# 12.07, 2, red, Entry
# 12.07, 1, red, Entry
# 12.07, 4, blue, Entry
# 12.11, 3, red, Entry
# 12.11, 4, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 4, red, Entry
# 12.11, 4, red, Entry
# 12.11, 4, red, Entry
# 12.11, 4, red, Entry
# 12.11, 4, red, Entry
# 12.11, 4, red, Entry
# 12.11, 4, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.11, 2, red, Entry
# 12.16, 3, red, Entry
# 12.16, 3, red, Entry
# 12.16, 4, red, Entry
# 12.16, 4, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 4, red, Entry
# 12.16, 4, red, Entry
# 12.16, 4, red, Entry
# 12.16, 4, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 2, red, Entry
# 12.16, 4, blue, Entry
# 12.20, 3, red, Entry
# 12.20, 3, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.20, 4, red, Entry
# 12.20, 4, red, Entry
# 12.20, 4, red, Entry
# 12.20, 4, red, Entry
# 12.20, 4, red, Entry
# 12.20, 4, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.20, 2, red, Entry
# 12.25, 4, red, Entry
# 12.25, 4, red, Entry
# 12.25, 4, red, Entry
# 12.25, 3, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.25, 4, red, Entry
# 12.25, 4, red, Entry
# 12.25, 4, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.25, 2, red, Entry
# 12.29, 3, red, Entry
# 12.29, 4, red, Entry
# 12.29, 4, red, Entry
# 12.29, 4, red, Entry
# 12.29, 3, red, Entry
# 12.29, 4, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 4, red, Entry
# 12.29, 4, red, Entry
# 12.29, 4, red, Entry
# 12.29, 4, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, red, Entry
# 12.29, 2, green, Entry
# 12.34, 4, red, Entry
# 12.34, 3, red, Entry
# 12.34, 2, red, Entry
# 12.34, 2, red, Entry
# 12.34, 2, red, Entry
# 12.34, 2, red, Entry
# 12.34, 4, red, Entry
# 12.34, 4, red, Entry
# 12.34, 4, red, Entry
# 12.34, 4, red, Entry
# 12.34, 4, red, Entry
# 12.34, 4, red, Entry
# 12.34, 4, red, Entry
# 12.34, 2, red, Entry
# 12.34, 2, red, Entry
# 12.34, 2, red, Entry
# 12.34, 2, red, Entry
# 12.34, 2, red, Entry
# 12.38, 3, red, Entry
# 12.38, 4, red, Entry
# 12.38, 4, red, Entry
# 12.38, 3, red, Entry
# 12.38, 2, red, Entry
# 12.38, 2, red, Entry
# 12.38, 2, red, Entry
# 12.38, 2, red, Entry
# 12.38, 4, red, Entry
# 12.38, 4, red, Entry
# 12.38, 4, red, Entry
# 12.38, 2, red, Entry
# 12.38, 2, red, Entry
# 12.38, 2, red, Entry
# 12.38, 2, red, Entry
# 12.38, 2, green, Entry
# 12.42, 4, red, Entry
# 12.42, 3, red, Entry
# 12.42, 4, red, Entry
# 12.42, 3, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.42, 4, red, Entry
# 12.42, 4, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.42, 2, red, Entry
# 12.47, 3, red, Entry
# 12.47, 4, red, Entry
# 12.47, 4, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 4, red, Entry
# 12.47, 4, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, red, Entry
# 12.47, 2, green, Entry
# 12.51, 3, red, Entry
# 12.51, 4, red, Entry
# 12.51, 4, red, Entry
# 12.51, 3, red, Entry
# 12.51, 2, red, Entry
# 12.51, 2, red, Entry
# 12.51, 2, green, Entry
# 12.55, 4, red, Entry
# 12.55, 4, red, Entry
# 12.55, 4, red, Entry
# 12.55, 4, red, Entry
# 12.55, 4, red, Entry
# 12.55, 4, red, Entry
# 12.55, 4, red, Entry
# 12.55, 2, red, Entry
# 12.55, 2, green, Entry
# 12.59, 4, red, Entry
# 12.59, 4, red, Entry
# 12.59, 2, red, Entry
# 12.59, 4, blue, Entry
# 12.59, 2, green, Entry
# 12.63, 3, red, Entry
# 12.63, 4, red, Entry
# 12.63, 4, red, Entry
# 12.63, 4, red, Entry
# 12.63, 3, red, Entry
# 12.63, 2, red, Entry
# 12.63, 4, blue, Entry
# 12.63, 2, green, Entry
# 12.67, 4, red, Entry
# 12.67, 3, red, Entry
# 12.67, 3, red, Entry
# 12.67, 2, green, Entry
# 12.71, 3, red, Entry
# 12.71, 3, red, Entry
# 12.71, 3, red, Entry
# 12.71, 2, red, Entry
# 12.71, 2, green, Entry
# 12.75, 3, red, Entry
# 12.75, 3, red, Entry
# 12.75, 2, green, Entry
# 12.78, 3, red, Entry
# 12.78, 3, red, Entry
# 12.78, 2, green, Entry
# 12.78, 2, green, Entry
# 12.83, 4, red, Entry
# 12.83, 3, red, Entry
# 12.83, 2, red, Entry
# 12.83, 2, green, Entry
# 12.86, 3, red, Entry
# 12.86, 2, green, Entry
# 12.90, 3, red, Entry
# 12.90, 3, red, Entry
# 12.90, 1, red, Entry
# 12.90, 2, red, Entry
# 12.90, 2, green, Entry
# 12.93, 3, red, Entry
# 12.93, 3, red, Entry
# 12.93, 4, red, Entry
# 12.93, 2, red, Entry
# 12.93, 2, green, Entry
# 12.99, 3, red, Entry
# 12.99, 3, red, Entry
# 12.99, 4, red, Entry
# 12.99, 2, green, Entry
# 13.03, 3, red, Entry
# 13.03, 3, red, Entry
# 13.03, 4, red, Entry
# 13.03, 3, red, Entry
# 13.03, 2, green, Entry
# 13.06, 3, red, Entry
# 13.06, 4, red, Entry
# 13.06, 4, red, Entry
# 13.06, 2, green, Entry
# 13.09, 3, red, Entry
# 13.09, 4, red, Entry
# 13.09, 2, green, Entry
# 13.14, 3, red, Entry
# 13.14, 4, red, Entry
# 13.14, 4, red, Entry
# 13.14, 2, red, Entry
# 13.14, 2, green, Entry
# 13.17, 3, red, Entry
# 13.17, 4, red, Entry
# 13.22, 4, red, Entry
# 13.22, 3, red, Entry
# 13.25, 3, red, Entry
# 13.25, 2, green, Entry
# 13.32, 3, red, Entry
# 13.32, 4, red, Entry
# 13.32, 2, red, Entry
# 13.32, 1, red, Entry
# 13.37, 3, red, Entry
# 13.37, 4, red, Entry
# 13.37, 1, red, Entry
# 13.37, 2, green, Entry
# 13.40, 3, red, Entry
# 13.40, 4, red, Entry
# 13.40, 4, blue, Entry
# 13.40, 2, green, Entry
# 13.45, 4, red, Entry
# 13.45, 3, red, Entry
# 13.45, 4, red, Entry
# 13.45, 3, red, Entry
# 13.45, 4, red, Entry
# 13.45, 2, red, Entry
# 13.49, 3, red, Entry
# 13.49, 4, red, Entry
# 13.49, 3, red, Entry
# 13.49, 1, red, Entry
# 13.49, 4, red, Entry
# 13.49, 2, red, Entry
# 13.52, 3, red, Entry
# 13.52, 4, red, Entry
# 13.55, 3, red, Entry
# 13.55, 2, red, Entry
# 13.55, 1, red, Entry
# 13.55, 2, green, Entry
# 13.60, 3, red, Entry
# 13.60, 4, red, Entry
# 13.60, 2, blue, Entry
# 13.60, 2, green, Entry
# 13.63, 3, red, Entry
# 13.63, 3, red, Entry
# 13.63, 4, red, Entry
# 13.63, 2, red, Entry
# 13.63, 2, green, Entry
# 13.68, 3, red, Entry
# 13.68, 3, red, Entry
# 13.68, 4, red, Entry
# 13.68, 2, blue, Entry
# 13.68, 2, green, Entry
# 13.71, 3, red, Entry
# 13.71, 4, red, Entry
# 13.71, 2, red, Entry
# 13.71, 4, blue, Entry
# 13.74, 3, red, Entry
# 13.74, 1, red, Entry
# 13.77, 3, red, Entry
# 13.77, 4, red, Entry
# 13.77, 2, red, Entry
# 13.77, 4, blue, Entry
# 13.77, 2, blue, Entry
# 13.82, 3, red, Entry
# 13.82, 4, red, Entry
# 13.82, 4, red, Entry
# 13.82, 4, blue, Entry
# 13.82, 2, blue, Entry
# 13.85, 4, red, Entry
# 13.85, 1, red, Entry
# 13.90, 3, red, Entry
# 13.90, 1, red, Entry
# 13.90, 2, red, Entry
# 13.90, 2, blue, Entry
# 13.94, 1, red, Entry
# 13.94, 1, red, Entry
# 13.94, 2, blue, Entry
# 13.98, 3, red, Entry
# 13.98, 1, red, Entry
# 13.98, 4, red, Entry
# 13.98, 2, red, Entry
# 13.98, 4, blue, Entry
# 14.01, 3, red, Entry
# 14.01, 1, red, Entry
# 14.05, 4, red, Entry
# 14.05, 1, red, Entry
# 14.08, 3, red, Entry
# 14.08, 1, red, Entry
# 14.08, 1, red, Entry
# 14.08, 4, blue, Entry
# 14.14, 3, red, Entry
# 14.14, 1, red, Entry
# 14.14, 2, blue, Entry
# 14.17, 3, red, Entry
# 14.21, 4, red, Entry
# 14.24, 2, red, Entry
# ...
# 140.77, 4, red, Entry
# 140.77, 4, red, Entry
# 140.77, 3, red, Entry
# 140.77, 4, red, Entry
# 140.77, 2, red, Entry
# 140.77, 2, green, Entry
# 140.82, 4, red, Entry
# 140.82, 3, red, Entry
# 140.82, 4, red, Entry
# 140.82, 2, red, Entry
# 140.82, 2, green, Entry
# 140.86, 4, red, Entry
# 140.86, 4, red, Entry
# 140.86, 4, red, Entry
# 140.86, 2, red, Entry
# 140.86, 2, green, Entry
# 140.86, 2, green, Entry
# 140.91, 4, red, Entry
# 140.91, 3, red, Entry
# 140.91, 4, red, Entry
# 140.91, 2, red, Entry
# 140.91, 1, red, Entry
# 140.91, 2, green, Entry
# 140.91, 2, green, Entry
# 140.95, 3, red, Entry
# 140.95, 1, red, Entry
# 140.95, 1, red, Entry
# 141.01, 4, red, Entry
# 141.01, 3, red, Entry
# 141.01, 4, red, Entry
# 141.01, 1, red, Entry
# 141.01, 4, red, Entry
# 141.01, 2, red, Entry
# 141.06, 4, red, Entry
# 141.06, 4, red, Entry
# 141.06, 4, red, Entry
# 141.06, 4, red, Entry
# 141.06, 1, red, Entry
# 141.06, 2, red, Entry
# 141.06, 4, blue, Entry
# 141.06, 2, green, Entry
# 141.10, 4, red, Entry
# 141.10, 4, red, Entry
# 141.10, 2, red, Entry
# 141.10, 2, red, Entry
# 141.10, 2, green, Entry
# 141.10, 2, green, Entry
# 141.15, 4, red, Entry
# 141.15, 4, red, Entry
# 141.15, 3, red, Entry
# 141.15, 4, red, Entry
# 141.15, 4, red, Entry
# 141.15, 4, red, Entry
# 141.15, 2, red, Entry
# 141.15, 4, blue, Entry
# 141.20, 4, red, Entry
# 141.20, 4, red, Entry
# 141.20, 4, red, Entry
# 141.20, 3, red, Entry
# 141.20, 1, red, Entry
# 141.20, 1, red, Entry
# 141.24, 4, red, Entry
# 141.24, 4, red, Entry
# 141.24, 4, red, Entry
# 141.24, 4, red, Entry
# 141.24, 3, red, Entry
# 141.24, 4, red, Entry
# 141.24, 2, green, Entry
# 141.29, 4, red, Entry
# 141.29, 4, red, Entry
# 141.29, 4, red, Entry
# 141.29, 4, red, Entry
# 141.29, 4, red, Entry
# 141.29, 3, red, Entry
# 141.29, 1, red, Entry
# 141.29, 2, red, Entry
# 141.34, 4, red, Entry
# 141.34, 4, red, Entry
# 141.34, 3, red, Entry
# 141.34, 4, red, Entry
# 141.34, 4, red, Entry
# 141.34, 4, red, Entry
# 141.34, 1, red, Entry
# 141.39, 4, red, Entry
# 141.39, 4, red, Entry
# 141.39, 4, red, Entry
# 141.39, 1, red, Entry
# 141.39, 2, red, Entry
# 141.39, 1, red, Entry
# 141.39, 2, green, Entry
# 141.44, 4, red, Entry
# 141.44, 4, red, Entry
# 141.44, 2, green, Entry
# 141.49, 4, red, Entry
# 141.49, 4, red, Entry
# 141.49, 4, red, Entry
# 141.49, 4, red, Entry
# 141.49, 4, red, Entry
# 141.49, 2, red, Entry
# 141.49, 1, red, Entry
# 141.49, 2, green, Entry
# 141.49, 2, green, Entry
# 141.53, 4, red, Entry
# 141.53, 4, red, Entry
# 141.53, 4, red, Entry
# 141.53, 4, red, Entry
# 141.53, 2, green, Entry
# 141.58, 3, red, Entry
# 141.58, 4, red, Entry
# 141.58, 4, red, Entry
# 141.58, 3, red, Entry
# 141.58, 2, red, Entry
# 141.58, 2, green, Entry
# 141.63, 3, red, Entry
# 141.63, 4, red, Entry
# 141.63, 4, red, Entry
# 141.63, 4, red, Entry
# 141.63, 1, red, Entry
# 141.63, 1, red, Entry
# 141.63, 2, green, Entry
# 141.63, 2, green, Entry
# 141.68, 4, red, Entry
# 141.68, 1, red, Entry
# 141.68, 2, red, Entry
# 141.68, 2, green, Entry
# 141.73, 4, red, Entry
# 141.73, 2, red, Entry
# 141.73, 2, green, Entry
# 141.78, 4, red, Entry
# 141.78, 2, green, Entry
# 141.82, 4, red, Entry
# 141.82, 4, red, Entry
# 141.82, 2, red, Entry
# 141.82, 2, red, Entry
# 141.82, 2, green, Entry
# 141.82, 2, green, Entry
# 141.87, 3, red, Entry
# 141.87, 4, red, Entry
# 141.87, 1, red, Entry
# 141.87, 2, red, Entry
# 141.91, 4, red, Entry
# 141.91, 4, red, Entry
# 141.91, 4, red, Entry
# 141.91, 4, red, Entry
# 141.91, 1, red, Entry
# 141.91, 1, red, Entry
# 141.91, 2, red, Entry
# 141.91, 1, red, Entry
# 141.91, 2, green, Entry
# 141.91, 2, green, Entry
# 141.97, 4, red, Entry
# 141.97, 4, red, Entry
# 141.97, 4, red, Entry
# 141.97, 2, red, Entry
# 141.97, 1, red, Entry
# 141.97, 2, green, Entry
# 142.01, 4, red, Entry
# 142.01, 4, red, Entry
# 142.01, 1, red, Entry
# 142.01, 2, red, Entry
# 142.01, 1, red, Entry
# 142.01, 2, green, Entry
# 142.06, 4, red, Entry
# 142.06, 4, red, Entry
# 142.06, 2, green, Entry
# 142.11, 3, red, Entry
# 142.11, 1, red, Entry
# 142.11, 2, green, Entry
# 142.17, 3, red, Entry
# 142.17, 4, red, Entry
# 142.22, 4, red, Entry
# 142.22, 4, red, Entry
# 142.22, 4, red, Entry
# 142.22, 2, green, Entry
# 142.22, 2, green, Entry
# 142.27, 3, red, Entry
# 142.27, 1, red, Entry
# 142.27, 2, green, Entry
# 142.31, 4, red, Entry
# 142.31, 4, red, Entry
# 142.31, 1, red, Entry
# 142.31, 3, red, Entry
# 142.35, 3, red, Entry
# 142.35, 4, red, Entry
# 142.35, 2, red, Entry
# 142.35, 2, red, Entry
# 142.35, 2, green, Entry
# 142.40, 4, red, Entry
# 142.40, 4, red, Entry
# 142.40, 3, red, Entry
# 142.40, 2, green, Entry
# 142.45, 4, red, Entry
# 142.45, 3, red, Entry
# 142.45, 1, red, Entry
# 142.45, 2, green, Entry
# 142.49, 4, red, Entry
# 142.49, 3, red, Entry
# 142.49, 2, green, Entry
# 142.56, 3, red, Entry
# 142.56, 4, red, Entry
# 142.56, 3, red, Entry
# 142.56, 1, red, Entry
# 142.56, 2, green, Entry
# 142.61, 3, red, Entry
# 142.61, 4, red, Entry
# 142.61, 3, red, Entry
# 142.61, 4, red, Entry
# 142.61, 1, red, Entry
# 142.61, 2, green, Entry
# 142.66, 4, red, Entry
# 142.66, 3, red, Entry
# 142.66, 2, green, Entry
# 142.71, 4, red, Entry
# 142.71, 2, red, Entry
# 142.71, 1, red, Entry
# 142.71, 2, green, Entry
# 142.75, 3, red, Entry
# 142.75, 3, red, Entry
# 142.75, 4, red, Entry
# 142.75, 4, red, Entry
# 142.75, 2, red, Entry
# 142.75, 2, green, Entry
# 142.75, 2, green, Entry
# 142.80, 3, red, Entry
# 142.80, 4, red, Entry
# 142.80, 4, red, Entry
# 142.80, 2, green, Entry
# 142.80, 2, green, Entry
# 142.84, 4, red, Entry
# 142.84, 4, red, Entry
# 142.84, 3, red, Entry
# 142.84, 4, red, Entry
# 142.84, 2, red, Entry
# 142.88, 3, red, Entry
# 142.88, 4, red, Entry
# 142.88, 4, red, Entry
# 142.88, 4, red, Entry
# 142.88, 2, red, Entry
# 142.88, 2, red, Entry
# 142.88, 2, green, Entry
# 142.88, 2, green, Entry
# 142.93, 4, red, Entry
# 142.93, 3, red, Entry
# 142.93, 4, red, Entry
# 142.93, 1, red, Entry
# 142.93, 1, red, Entry
# 142.93, 2, green, Entry
# 142.97, 4, red, Entry
# 142.97, 4, red, Entry
# 142.97, 2, red, Entry
# 142.97, 2, red, Entry
# 142.97, 1, red, Entry
# 142.97, 2, green, Entry
# 143.01, 4, red, Entry
# 143.01, 3, red, Entry
# 143.01, 4, red, Entry
# 143.01, 2, red, Entry
# 143.01, 1, red, Entry
# 143.01, 2, green, Entry
# 143.06, 4, red, Entry
# 143.06, 4, red, Entry
# 143.06, 2, red, Entry
# 143.06, 2, green, Entry
# 143.10, 3, red, Entry
# 143.10, 4, red, Entry
# 143.10, 4, red, Entry
# 143.10, 4, red, Entry
# 143.10, 2, red, Entry
# 143.10, 1, red, Entry
# 143.14, 4, red, Entry
# 143.14, 3, red, Entry
# 143.14, 4, red, Entry
# 143.14, 4, red, Entry
# 143.14, 2, red, Entry
# 143.14, 2, red, Entry
# 143.14, 2, green, Entry
# 143.19, 4, red, Entry
# 143.19, 3, red, Entry
# 143.19, 4, red, Entry
# 143.19, 1, red, Entry
# 143.23, 4, red, Entry
# 143.23, 1, red, Entry
# 143.23, 1, red, Entry
# 143.23, 2, green, Entry
# 143.28, 3, red, Entry
# 143.28, 4, red, Entry
# 143.28, 4, red, Entry
# 143.28, 2, green, Entry
# 143.32, 3, red, Entry
# 143.32, 4, red, Entry
# 143.32, 4, red, Entry
# 143.32, 2, green, Entry
# 143.32, 2, green, Entry
# 143.36, 4, red, Entry
# 143.36, 2, red, Entry
# 143.36, 4, red, Entry
# 143.41, 4, red, Entry
# 143.41, 1, red, Entry
# 143.41, 2, green, Entry
# 143.46, 4, red, Entry
# 143.46, 3, red, Entry
# 143.50, 4, red, Entry
# 143.50, 4, red, Entry
# 143.50, 2, green, Entry
# 143.54, 4, red, Entry
# 143.54, 4, red, Entry
# 143.54, 2, green, Entry
# 143.54, 2, green, Entry
# 143.58, 4, red, Entry
# 143.58, 4, red, Entry
# 143.58, 4, red, Entry
# 143.58, 2, green, Entry
# 143.63, 3, red, Entry
# 143.63, 3, red, Entry
# 143.63, 4, red, Entry
# 143.63, 3, red, Entry
# 143.63, 4, red, Entry
# 143.63, 2, green, Entry
# 143.67, 3, red, Entry
# 143.67, 3, red, Entry
# 143.67, 2, red, Entry
# 143.67, 2, green, Entry
# 143.71, 4, red, Entry
# 143.71, 2, red, Entry
# 143.71, 2, green, Entry
# 143.71, 2, green, Entry
# 143.75, 4, red, Entry
# 143.75, 2, red, Entry
# 143.75, 3, red, Entry
# 143.80, 4, red, Entry
# 143.80, 4, red, Entry
# 143.80, 3, red, Entry
# 143.80, 1, red, Entry
# 143.80, 2, red, Entry
# 143.80, 1, red, Entry
# 143.80, 2, green, Entry
# 143.85, 3, red, Entry
# 143.85, 4, red, Entry
# 143.85, 4, red, Entry
# 143.85, 2, red, Entry
# 143.89, 3, red, Entry
# 143.89, 4, red, Entry
# 143.89, 2, red, Entry
# 143.89, 2, green, Entry
# 143.89, 2, green, Entry
# 143.89, 2, green, Entry
# 143.93, 3, red, Entry
# 143.93, 4, red, Entry
# 143.93, 2, red, Entry
# 143.93, 2, red, Entry
# 143.93, 2, green, Entry
# 143.93, 2, green, Entry
# 143.93, 2, green, Entry
# 143.98, 3, red, Entry
# 143.98, 4, red, Entry
# 143.98, 2, red, Entry
# 143.98, 2, red, Entry
# 143.98, 1, red, Entry
# 143.98, 2, green, Entry
# 143.98, 2, green, Entry
# 144.02, 4, red, Entry
# 144.02, 2, red, Entry
# 144.02, 2, green, Entry
# 144.06, 4, red, Entry
# 144.06, 3, red, Entry
# 144.06, 3, red, Entry
# 144.06, 3, red, Entry
# 144.06, 4, red, Entry
# 144.06, 1, red, Entry
# 144.06, 2, red, Entry
# 144.06, 2, green, Entry
# 144.11, 3, red, Entry
# 144.11, 4, red, Entry
# 144.11, 4, red, Entry
# 144.11, 3, red, Entry
# 144.11, 2, red, Entry
# 144.11, 1, red, Entry
# 144.11, 2, red, Entry
# 144.11, 2, green, Entry
# 144.11, 2, green, Entry
# 144.16, 3, red, Entry
# 144.16, 4, red, Entry
# 144.16, 4, red, Entry
# 144.16, 2, red, Entry
# 144.16, 2, red, Entry
# 144.16, 1, red, Entry
# 144.16, 2, green, Entry
# 144.20, 3, red, Entry
# 144.20, 4, red, Entry
# 144.20, 4, red, Entry
# 144.20, 2, red, Entry
# 144.20, 1, red, Entry
# 144.20, 2, red, Entry
# 144.20, 2, green, Entry
# 144.24, 4, red, Entry
# 144.24, 1, red, Entry
# 144.24, 2, green, Entry
# 144.24, 2, green, Entry
# 144.29, 4, red, Entry
# 144.29, 4, red, Entry
# 144.29, 4, red, Entry
# 144.29, 2, green, Entry
# 144.33, 4, red, Entry
# 144.33, 3, red, Entry
# 144.33, 1, red, Entry
# 144.38, 4, red, Entry
# 144.38, 3, red, Entry
# 144.38, 1, red, Entry
# 144.38, 1, red, Entry
# 144.38, 2, green, Entry
# 144.42, 4, red, Entry
# 144.42, 3, red, Entry
# 144.42, 4, red, Entry
# 144.42, 4, red, Entry
# 144.42, 3, red, Entry
# 144.42, 1, red, Entry
# 144.42, 2, red, Entry
# 144.42, 1, red, Entry
# 144.42, 2, green, Entry
# 144.46, 3, red, Entry
# 144.46, 3, red, Entry
# 144.46, 1, red, Entry
# 144.46, 2, green, Entry
# 144.46, 2, green, Entry
# 144.51, 4, red, Entry
# 144.51, 2, red, Entry
# 144.51, 2, green, Entry
# 144.51, 2, green, Entry
# 144.55, 4, red, Entry
# 144.55, 4, red, Entry
# 144.55, 3, red, Entry
# 144.55, 4, red, Entry
# 144.55, 1, red, Entry
# 144.55, 1, red, Entry
# 144.60, 4, red, Entry
# 144.60, 3, red, Entry
# 144.60, 1, red, Entry
# 144.64, 4, red, Entry
# 144.64, 3, red, Entry
# 144.64, 1, red, Entry
# 144.64, 2, red, Entry
# 144.64, 2, green, Entry
# 144.69, 3, red, Entry
# 144.69, 4, red, Entry
# 144.69, 1, red, Entry
# 144.69, 3, red, Entry
# 144.69, 2, red, Entry
# 144.69, 2, green, Entry
# 144.73, 3, red, Entry
# 144.73, 4, red, Entry
# 144.73, 4, red, Entry
# 144.73, 3, red, Entry
# 144.73, 4, red, Entry
# 144.77, 3, red, Entry
# 144.77, 4, red, Entry
# 144.77, 3, red, Entry
# 144.82, 3, red, Entry
# 144.82, 3, red, Entry
# 144.82, 2, red, Entry
# 144.82, 2, red, Entry
# 144.82, 2, red, Entry
# 144.86, 3, red, Entry
# 144.86, 3, red, Entry
# 144.86, 2, green, Entry
# 144.90, 2, red, Entry
# 144.90, 2, green, Entry
# 144.94, 3, red, Entry
# 144.94, 3, red, Entry
# 144.94, 2, red, Entry
# 144.94, 2, green, Entry
# 144.99, 3, red, Entry
# 144.99, 4, red, Entry
# 144.99, 2, red, Entry
# 145.03, 3, red, Entry
# 145.03, 4, red, Entry
# 145.03, 2, red, Entry
# 145.03, 3, red, Entry
# 145.03, 2, green, Entry
# 145.07, 3, red, Entry
# 145.07, 2, red, Entry
# 145.07, 1, red, Entry
# 145.07, 1, red, Entry
# 145.12, 3, red, Entry
# 145.12, 4, red, Entry
# 145.12, 4, red, Entry
# 145.12, 3, red, Entry
# 145.12, 2, red, Entry
# 145.16, 3, red, Entry
# 145.16, 4, red, Entry
# 145.16, 4, red, Entry
# 145.16, 3, red, Entry
# 145.16, 2, green, Entry
# 145.21, 3, red, Entry
# 145.21, 4, red, Entry
# 145.21, 3, red, Entry
# 145.21, 2, red, Entry
# 145.21, 2, red, Entry
# 145.21, 4, red, Entry
# 145.21, 2, green, Entry
# 145.21, 2, green, Entry
# 145.24, 3, red, Entry
# 145.24, 3, red, Entry
# 145.24, 2, red, Entry
# 145.24, 3, red, Entry
# 145.24, 4, red, Entry
# 145.29, 4, red, Entry
# 145.29, 3, red, Entry
# 145.29, 4, red, Entry
# 145.29, 2, green, Entry
# 145.29, 2, green, Entry
# 145.33, 4, red, Entry
# 145.33, 3, red, Entry
# 145.33, 3, red, Entry
# 145.33, 2, red, Entry
# 145.33, 4, red, Entry
# 145.33, 2, green, Entry
# 145.38, 4, red, Entry
# 145.38, 3, red, Entry
# 145.38, 4, red, Entry
# 145.38, 4, red, Entry
# 145.38, 1, red, Entry
# 145.38, 2, red, Entry
# 145.38, 2, green, Entry
# 145.42, 3, red, Entry
# 145.42, 3, red, Entry
# 145.42, 4, red, Entry
# 145.42, 2, red, Entry
# 145.42, 2, green, Entry
# 145.46, 3, red, Entry
# 145.46, 3, red, Entry
# 145.46, 2, red, Entry
# 145.46, 1, red, Entry
# 145.51, 3, red, Entry
# 145.51, 4, red, Entry
# 145.55, 3, red, Entry
# 145.55, 3, red, Entry
# 145.55, 4, red, Entry
# 145.55, 4, red, Entry
# 145.55, 2, red, Entry
# 145.55, 2, red, Entry
# 145.55, 2, green, Entry
# 145.60, 3, red, Entry
# 145.60, 3, red, Entry
# 145.60, 1, red, Entry
# 145.60, 4, red, Entry
# 145.60, 2, red, Entry
# 145.64, 3, red, Entry
# 145.64, 3, red, Entry
# 145.64, 2, red, Entry
# 145.64, 2, red, Entry
# 145.64, 4, red, Entry
# 145.64, 1, red, Entry
# 145.64, 2, red, Entry
# 145.64, 2, green, Entry
# 145.69, 4, red, Entry
# 145.69, 3, red, Entry
# 145.69, 1, red, Entry
# 145.73, 3, red, Entry
# 145.73, 3, red, Entry
# 145.73, 4, red, Entry
# 145.73, 3, red, Entry
# 145.73, 4, red, Entry
# 145.73, 1, red, Entry
# 145.73, 2, red, Entry
# 145.73, 4, red, Entry
# 145.77, 2, red, Entry
# 145.77, 2, green, Entry
# 145.82, 4, red, Entry
# 145.82, 3, red, Entry
# 145.82, 2, green, Entry
# 145.86, 3, red, Entry
# 145.86, 3, red, Entry
# 145.86, 2, red, Entry
# 145.86, 4, red, Entry
# 145.86, 2, red, Entry
# 145.86, 2, green, Entry
# 145.86, 2, green, Entry
# 145.90, 3, red, Entry
# 145.90, 1, red, Entry
# 145.90, 4, red, Entry
# 145.90, 2, red, Entry
# 145.95, 3, red, Entry
# 145.95, 2, red, Entry
# 145.95, 3, red, Entry
# 145.95, 4, red, Entry
# 145.99, 4, red, Entry
# 145.99, 4, red, Entry
# 145.99, 3, red, Entry
# 145.99, 2, red, Entry
# 145.99, 2, green, Entry
# 145.99, 2, green, Entry
# 146.03, 4, red, Entry
# 146.03, 4, red, Entry
# 146.03, 4, red, Entry
# 146.03, 2, red, Entry
# 146.03, 1, red, Entry
# 146.08, 4, red, Entry
# 146.08, 2, red, Entry
# 146.12, 3, red, Entry
# 146.12, 4, red, Entry
# 146.12, 4, red, Entry
# 146.12, 2, red, Entry
# 146.16, 4, red, Entry
# 146.16, 4, red, Entry
# 146.16, 3, red, Entry
# 146.16, 2, green, Entry
# 146.21, 3, red, Entry
# 146.21, 4, red, Entry
# 146.21, 4, red, Entry
# 146.21, 2, green, Entry
# 146.21, 2, green, Entry
# 146.25, 3, red, Entry
# 146.25, 2, red, Entry
# 146.25, 2, red, Entry
# 146.29, 3, red, Entry
# 146.29, 4, red, Entry
# 146.29, 2, red, Entry
# 146.29, 2, green, Entry
# 146.29, 2, green, Entry
# 146.33, 4, red, Entry
# 146.33, 3, red, Entry
# 146.33, 4, red, Entry
# 146.33, 2, red, Entry
# 146.38, 4, red, Entry
# 146.38, 1, red, Entry
# 146.42, 3, red, Entry
# 146.42, 3, red, Entry
# 146.42, 4, red, Entry
# 146.42, 4, red, Entry
# 146.42, 1, red, Entry
# 146.42, 1, red, Entry
# 146.47, 3, red, Entry
# 146.51, 4, red, Entry
# 146.51, 3, red, Entry
# 146.51, 1, red, Entry
# 146.56, 3, red, Entry
# 146.56, 4, red, Entry
# 146.56, 3, red, Entry
# 146.56, 2, red, Entry
# 146.60, 3, red, Entry
# 146.60, 3, red, Entry
# 146.60, 2, red, Entry
# 146.65, 4, red, Entry
# 146.65, 3, red, Entry
# 146.65, 2, red, Entry
# 146.65, 1, red, Entry
# 146.65, 2, red, Entry
# 146.69, 3, red, Entry
# 146.69, 3, red, Entry
# 146.69, 2, red, Entry
# 146.69, 2, red, Entry
# 146.69, 1, red, Entry
# 146.69, 2, red, Entry
# 146.73, 3, red, Entry
# 146.73, 2, red, Entry
# 146.73, 2, green, Entry
# 146.78, 3, red, Entry
# 146.78, 2, red, Entry
# 146.78, 2, green, Entry
# 146.82, 4, red, Entry
# 146.82, 3, red, Entry
# 146.82, 2, red, Entry
# 146.82, 2, green, Entry
# 146.87, 4, red, Entry
# 146.87, 3, red, Entry
# 146.87, 2, red, Entry
# 146.92, 4, red, Entry
# 146.92, 3, red, Entry
# 146.92, 1, red, Entry
# 146.96, 3, red, Entry
# 146.96, 4, red, Entry
# 146.96, 4, red, Entry
# 146.96, 3, red, Entry
# 147.01, 4, red, Entry
# 147.01, 3, red, Entry
# 147.01, 2, red, Entry
# 147.01, 1, red, Entry
# 147.05, 4, red, Entry
# 147.05, 4, red, Entry
# 147.05, 3, red, Entry
# 147.05, 2, red, Entry
# 147.05, 2, red, Entry
# 147.05, 1, red, Entry
# 147.05, 2, red, Entry
# 147.09, 3, red, Entry
# 147.09, 4, red, Entry
# 147.09, 3, red, Entry
# 147.09, 2, green, Entry
# 147.09, 2, green, Entry
# 147.14, 3, red, Entry
# 147.14, 2, red, Entry
# 147.18, 3, red, Entry
# 147.18, 4, red, Entry
# 147.18, 2, green, Entry
# 147.22, 4, red, Entry
# 147.22, 3, red, Entry
# 147.22, 1, red, Entry
# 147.22, 2, red, Entry
# 147.22, 2, green, Entry
# 147.26, 3, red, Entry
# 147.26, 4, red, Entry
# 147.26, 3, red, Entry
# 147.26, 2, red, Entry
# 147.26, 2, green, Entry
# 147.30, 4, red, Entry
# 147.34, 4, red, Entry
# 147.34, 3, red, Entry
# 147.34, 2, red, Entry
# 147.34, 2, red, Entry
# 147.34, 1, red, Entry
# 147.39, 3, red, Entry
# 147.39, 4, red, Entry
# 147.39, 3, red, Entry
# 147.39, 2, red, Entry
# 147.39, 2, red, Entry
